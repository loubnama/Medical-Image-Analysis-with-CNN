# %%
train_dir = '/kaggle/input/glaucoma-dataset-eyepacs-airogs-light-v2/eyepac-light-v2-512-jpg/train'
val_dir = '/kaggle/input/glaucoma-dataset-eyepacs-airogs-light-v2/eyepac-light-v2-512-jpg/validation'

# %%
from google.colab import files
files.upload()  # ارفع ملف kaggle.json

# إنشاء مجلد لتخزين ملف kaggle.json وتحريك الملف إليه
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# تأكد من تثبيت kaggle API
# !pip install -q kaggle

# تحميل مجموعة البيانات
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia

# فك الضغط
# !unzip -q chest-xray-pneumonia.zip -d chest-xray-pneumonia
# Out:
#      <input type="file" id="files-d502bf65-578a-41b8-8fb0-827f985c1d2b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d502bf65-578a-41b8-8fb0-827f985c1d2b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
files.upload()  # ارفع ملف kaggle.json
# Out:
#      <input type="file" id="files-f2c0ba88-ff35-42b7-87f0-3d126c33737c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f2c0ba88-ff35-42b7-87f0-3d126c33737c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !pip install -q kaggle

# %%
# !kaggle datasets download -d paultimothymooney/chest-xray-pneumonia
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/paultimothymooney/chest-xray-pneumonia
# License(s): other
# chest-xray-pneumonia.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# !unzip -o chest-xray-pneumonia.zip -d chest-xray-pneumonia
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0435-0001-0001.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0435-0001.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0437-0001-0001.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0437-0001-0002.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0437-0001.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0438-0001.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0439-0001-0001.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0439-0001-0002.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0439-0001.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0440-0001.jpeg
#   inflating: chest-xray-pneumonia/chest_xray/train/NORMAL/IM-0441-0001.jpeg
# ...

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
base_dir = 'chest-xray-pneumonia/chest_xray'
categories = ['train', 'test', 'val']
for category in categories:
    print(f"\nCategory: {category}")
    category_path = os.path.join(base_dir, category)
    subcategories = os.listdir(category_path)
    for subcategory in subcategories:
        subcategory_path = os.path.join(category_path, subcategory)
        num_images = len(os.listdir(subcategory_path))
        print(f" - {subcategory}: {num_images} images")

def show_image(image_path):
    img = Image.open(image_path)
    plt.imshow(img)
    plt.axis('off')
    plt.show()

sample_image_path = os.path.join(base_dir, 'train', 'NORMAL', os.listdir(os.path.join(base_dir, 'train', 'NORMAL'))[0])
show_image(sample_image_path)
# Out:
# Category: train
#  - PNEUMONIA: 3875 images
#  - NORMAL: 1341 images
#
# Category: test
#  - PNEUMONIA: 390 images
#  - NORMAL: 234 images
#
# Category: val
#  - PNEUMONIA: 8 images
#  - NORMAL: 8 images

# %%
import pandas as pd

data = {
    'Category': [],
    'Subcategory': [],
    'Number of Images': []
}

for category in categories:
    category_path = os.path.join(base_dir, category)
    subcategories = os.listdir(category_path)
    for subcategory in subcategories:
        subcategory_path = os.path.join(category_path, subcategory)
        num_images = len(os.listdir(subcategory_path))
        data['Category'].append(category)
        data['Subcategory'].append(subcategory)
        data['Number of Images'].append(num_images)

df = pd.DataFrame(data)
print(df)
# Out:
#   Category Subcategory  Number of Images
# 0    train   PNEUMONIA              3875
# 1    train      NORMAL              1341
# 2     test   PNEUMONIA               390
# 3     test      NORMAL               234
# 4      val   PNEUMONIA                 8
# 5      val      NORMAL                 8

# %%
##2
from google.colab import files
import os
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
def load_and_preprocess_image(image_path, target_size=(150, 150)):
    img = Image.open(image_path).convert('RGB')
    img = img.resize(target_size)
    img_array = np.array(img)
    img_array = img_array / 255.0
    return img_array

def load_data_from_directory(directory, target_size=(150, 150)):
    images = []
    labels = []
    for label in os.listdir(directory):
        label_path = os.path.join(directory, label)
        if os.path.isdir(label_path):
            for img_file in os.listdir(label_path):
                img_path = os.path.join(label_path, img_file)
                img_array = load_and_preprocess_image(img_path, target_size)
                images.append(img_array)
                labels.append(label)
    return np.array(images), np.array(labels)

train_path = os.path.join(base_dir, 'train')
test_path = os.path.join(base_dir, 'test')

train_images, train_labels = load_data_from_directory(train_path)
test_images, test_labels = load_data_from_directory(test_path)

x_train, x_val, y_train, y_val = train_test_split(train_images, train_labels, test_size=0.2, random_state=42)

print(f"Training set: {x_train.shape}, {y_train.shape}")
print(f"Validation set: {x_val.shape}, {y_val.shape}")
print(f"Test set: {test_images.shape}, {test_labels.shape}")

data = {
    'Category': [],
    'Subcategory': [],
    'Number of Images': []
}

for category in categories:
    category_path = os.path.join(base_dir, category)
    subcategories = os.listdir(category_path)
    for subcategory in subcategories:
        subcategory_path = os.path.join(category_path, subcategory)
        num_images = len(os.listdir(subcategory_path))
        data['Category'].append(category)
        data['Subcategory'].append(subcategory)
        data['Number of Images'].append(num_images)

df = pd.DataFrame(data)
print(df)
# Out:
# Training set: (4172, 150, 150, 3), (4172,)
# Validation set: (1044, 150, 150, 3), (1044,)
# Test set: (624, 150, 150, 3), (624,)
#   Category Subcategory  Number of Images
# 0    train   PNEUMONIA              3875
# 1    train      NORMAL              1341
# 2     test   PNEUMONIA               390
# 3     test      NORMAL               234
# 4      val   PNEUMONIA                 8
# 5      val      NORMAL                 8

# %%
#3 &4
from sklearn.preprocessing import LabelEncoder
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_val_encoded = label_encoder.transform(y_val)
test_labels_encoded = label_encoder.transform(test_labels)

train_datagen = ImageDataGenerator(rotation_range=10, zoom_range=0.1, horizontal_flip=True)
val_datagen = ImageDataGenerator()

train_generator = train_datagen.flow(x_train, y_train_encoded, batch_size=32)
val_generator = val_datagen.flow(x_val, y_val_encoded, batch_size=32)

def create_model(activation='relu', dropout_rate=0.5, learning_rate=0.001):
    model = Sequential([
        Conv2D(32, (3, 3), activation=activation, input_shape=(150, 150, 3)),
        MaxPooling2D((2, 2)),
        Conv2D(64, (3, 3), activation=activation),
        MaxPooling2D((2, 2)),
        Conv2D(128, (3, 3), activation=activation),
        MaxPooling2D((2, 2)),
        Flatten(),
        Dense(512, activation=activation),
        Dropout(dropout_rate),
        Dense(1, activation='sigmoid')
    ])

    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

model_1 = create_model(activation='relu', dropout_rate=0.5, learning_rate=0.001)
history_1 = model_1.fit(train_generator, validation_data=val_generator, epochs=3)

y_pred = (model_1.predict(test_images) > 0.5).astype("int32")

accuracy = accuracy_score(test_labels_encoded, y_pred)
precision = precision_score(test_labels_encoded, y_pred)
recall = recall_score(test_labels_encoded, y_pred)
f1 = f1_score(test_labels_encoded, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

conf_matrix = confusion_matrix(test_labels_encoded, y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

print('Classification Report:')
print(classification_report(test_labels_encoded, y_pred, target_names=label_encoder.classes_))
# Out:
# Epoch 1/3
# 131/131 [==============================] - 239s 2s/step - loss: 0.4071 - accuracy: 0.8325 - val_loss: 0.2125 - val_accuracy: 0.9167
# Epoch 2/3
# 131/131 [==============================] - 234s 2s/step - loss: 0.2203 - accuracy: 0.9175 - val_loss: 0.1096 - val_accuracy: 0.9636
# Epoch 3/3
# ...
# 20/20 [==============================] - 7s 331ms/step
# Accuracy: 0.7516025641025641
# Precision: 0.719626168224299
# Recall: 0.9871794871794872
# F1 Score: 0.8324324324324324
# Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.94      0.36      0.52       234
#    PNEUMONIA       0.72      0.99      0.83       390
#
#     accuracy                           0.75       624
#    macro avg       0.83      0.67      0.68       624
# weighted avg       0.80      0.75      0.72       624

# %%
#5
configurations = [
    {'activation': 'relu', 'dropout_rate': 0.5, 'learning_rate': 0.001},
    {'activation': 'tanh', 'dropout_rate': 0.3, 'learning_rate': 0.01},
    {'activation': 'sigmoid', 'dropout_rate': 0.7, 'learning_rate': 0.0001}
]

for config in configurations:
    print(f"\nTesting configuration: {config}")

    model = create_model(**config)

    history = model.fit(train_generator, validation_data=val_generator, epochs=3)

    y_pred = (model.predict(test_images) > 0.5).astype("int32")

    accuracy = accuracy_score(test_labels_encoded, y_pred)
    precision = precision_score(test_labels_encoded, y_pred)
    recall = recall_score(test_labels_encoded, y_pred)
    f1 = f1_score(test_labels_encoded, y_pred)

    print(f'Configuration: {config}')
    print(f'Accuracy: {accuracy}')
    print(f'Precision: {precision}')
    print(f'Recall: {recall}')
    print(f'F1 Score: {f1}')

    conf_matrix = confusion_matrix(test_labels_encoded, y_pred)

    plt.figure(figsize=(10, 7))
    sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title(f'Confusion Matrix - Config: {config}')
    plt.show()

    print('Classification Report:')
    print(classification_report(test_labels_encoded, y_pred, target_names=label_encoder.classes_))
# Out:
# Testing configuration: {'activation': 'relu', 'dropout_rate': 0.5, 'learning_rate': 0.001}
# Epoch 1/3
# 131/131 [==============================] - 251s 2s/step - loss: 0.3838 - accuracy: 0.8356 - val_loss: 0.1465 - val_accuracy: 0.9435
# Epoch 2/3
# 131/131 [==============================] - 230s 2s/step - loss: 0.2048 - accuracy: 0.9216 - val_loss: 0.1191 - val_accuracy: 0.9569
# Epoch 3/3
# ...
# 20/20 [==============================] - 7s 332ms/step
# Configuration: {'activation': 'relu', 'dropout_rate': 0.5, 'learning_rate': 0.001}
# Accuracy: 0.7387820512820513
# Precision: 0.7097966728280961
# Recall: 0.9846153846153847
# F1 Score: 0.8249194414607948
# Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.93      0.33      0.49       234
#    PNEUMONIA       0.71      0.98      0.82       390
#
#     accuracy                           0.74       624
#    macro avg       0.82      0.66      0.66       624
# ...

# %%
#6
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

y_pred = (model_1.predict(test_images) > 0.5).astype("int32")


accuracy = accuracy_score(test_labels_encoded, y_pred)
precision = precision_score(test_labels_encoded, y_pred)
recall = recall_score(test_labels_encoded, y_pred)
f1 = f1_score(test_labels_encoded, y_pred)

print(f'Accuracy: {accuracy}')
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1 Score: {f1}')

conf_matrix = confusion_matrix(test_labels_encoded, y_pred)

plt.figure(figsize=(10, 7))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

print('Classification Report:')
print(classification_report(test_labels_encoded, y_pred, target_names=label_encoder.classes_))
# Out:
# 20/20 [==============================] - 8s 390ms/step
# Accuracy: 0.7516025641025641
# Precision: 0.719626168224299
# Recall: 0.9871794871794872
# F1 Score: 0.8324324324324324
# Classification Report:
#               precision    recall  f1-score   support
#
#       NORMAL       0.94      0.36      0.52       234
#    PNEUMONIA       0.72      0.99      0.83       390
#
#     accuracy                           0.75       624
#    macro avg       0.83      0.67      0.68       624
# weighted avg       0.80      0.75      0.72       624
